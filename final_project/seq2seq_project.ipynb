# %% [markdown]
# # Word2Vec and Seq2Seq Project
#
# This notebook is designed to use a Word2Vec model to process textual data, followed by a sequence-to-sequence (Seq2Seq) neural network architecture.
# The Seq2Seq model will be trained to predict article titles from abstracts, transforming each input sequence of word embeddings into a target sequence.

# %%
# Load the necessary libraries
import pandas as pd

# Load data (assuming a similar CSV file with 'abstract' and 'title' columns)
articles = pd.read_csv('../final_project/NYT/NYT_Dataset_Preprocessed.csv')

articles = articles[articles['preprocessed_abstract'] != '']
articles = articles[articles['preprocessed_title'] != '']
articles = articles[articles['preprocessed_keywords'] != '']

articles = articles[(articles['preprocessed_abstract'].apply(type) == str) &
                    (articles['preprocessed_title'].apply(type) == str)]

abstracts = articles['preprocessed_abstract']
titles = articles['preprocessed_title']
keywords = articles['preprocessed_keywords']

print("Data loaded successfully.")
print(f"Sample abstract: {abstracts.iloc[0]}")
print(f"Sample title: {titles.iloc[0]}")
print(f"Sample keywords: {keywords.iloc[0]}")
# Out:
# Data loaded successfully.
# Sample abstract: pakistan ambassador u said government would endorse separate inquiry modeled one carried u n assassination rafik hariri lebanon 2005
# Sample title: reversal pakistan welcome outside help inquiry bhutto
# Sample keywords: ['assassination attempted assassination', 'pakistan', 'bhutto benazir', 'federal bureau investigation', 'united nation']

# %%
# Import necessary libraries for Word2Vec
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize

# Tokenize abstracts for Word2Vec training
abstracts_tokenized = [word_tokenize(abstract.lower()) for abstract in abstracts]

# "Train" Word2Vec model
word2vec_model = Word2Vec(sentences=abstracts_tokenized, vector_size=100, window=5, min_count=2, workers=4)

# Example of retrieving word vectors
sample_word = "example"
if sample_word in word2vec_model.wv:
    print(f"Vector for '{sample_word}': {word2vec_model.wv[sample_word]}")
else:
    print(f"'{sample_word}' not in vocabulary.")
# Out:
# Vector for 'example': [-0.05913113  0.27169517  0.0590232  -0.13798061 -0.2831471  -0.6246296
#  -0.27181587  0.74478906 -0.26388487  0.2583592  -0.06662034  0.11616062
#  -0.6762518   0.19939935 -0.09089735 -0.15078533  0.2705024  -0.37845543
#  -0.05315786 -0.54115     0.15202066  0.01698012  0.49734187  0.06917489
#  -0.11187842 -0.03796555 -0.16971691 -0.50890833 -0.1737636   0.268011
#   0.11165025 -0.11699247  0.17932595 -0.47495317  0.56669956  0.144165
#   0.23882341  0.02605644  0.4227661  -0.3308594  -0.29068613  0.03540949
#  -0.15051241  0.03239902  0.17510875 -0.32569832 -0.5801519  -0.25071952
#  -0.29022154  0.0925482   0.01482133 -0.03597991 -0.2805173   0.2923417
#   0.29262242  0.3938807   0.2625209   0.30393863 -0.09936269  0.04643556
#   0.11571067  0.21628615 -0.7251391  -0.23639937 -0.13608964  0.36544597
#   0.52631587  0.4848516  -0.14277932  0.31991404 -0.2088836  -0.25399607
#  -0.31199712  0.05175032  0.16974089  0.12479095 -0.23159651  0.28848618
#  -0.24661824 -0.00135885 -0.24421373  0.5546826  -0.01898761  0.13323805
#   0.05097387 -0.17430003 -0.4322969   0.29378408  0.43206924  0.5107607
#   0.03696674 -0.05645956 -0.04820693  0.16198193  0.23065649 -0.08092558
#   0.50570387 -0.5395279  -0.26665014  0.03813556]

# %%
import torch.nn as nn

class Encoder(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(Encoder, self).__init__()
        # Removed embedding layer as we are already working with precomputed embeddings
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True)

    def forward(self, src):
        # No need for embedding, just pass the input (already embeddings) to LSTM
        outputs, (hidden, cell) = self.lstm(src)
        return hidden, cell

class Decoder(nn.Module):
    def __init__(self, output_size, hidden_size):
        super(Decoder, self).__init__()
        self.embedding = nn.Embedding(output_size, hidden_size)
        self.lstm = nn.LSTM(hidden_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, trg, hidden, cell):
        embedded = self.embedding(trg)
        outputs, (hidden, cell) = self.lstm(embedded, (hidden, cell))
        predictions = self.fc(outputs)
        return predictions, hidden, cell

class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder):
        super(Seq2Seq, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, src, trg):
        hidden, cell = self.encoder(src)
        outputs, _, _ = self.decoder(trg, hidden, cell)
        return outputs

# %%
import numpy as np
from collections import defaultdict

max_len = 50
word2vec_model = Word2Vec(vector_size=100, window=5, min_count=1)

# %%
# Look at this
def build_vocab(titles):
    word_freq = defaultdict(int)
    for title in titles:
        for word in word_tokenize(title.lower()):
            word_freq[word] += 1
    return {word: idx + 1 for idx, (word, _) in enumerate(word_freq.items())}

def encode_title(title, word2idx, max_len):
    tokens = [word2idx.get(word, 0) for word in word_tokenize(title.lower())]  # 0 for unknown words
    return tokens[:max_len] + [0] * (max_len - len(tokens))

def embed_text(text, word2vec, max_len):
    pad_vector = np.zeros(word2vec.vector_size)
    tokens = word_tokenize(text.lower())
    embeddings = [word2vec.wv[token] if token in word2vec.wv else pad_vector for token in tokens]
    if len(embeddings) < max_len:
        embeddings += [pad_vector] * (max_len - len(embeddings))  # Pad to max_len
    return np.array(embeddings[:max_len])

# %%
word2idx = build_vocab(titles)

embedded_abstracts = [embed_text(abstract, word2vec_model, max_len) for abstract in abstracts]
embedded_keywords = [embed_text(keyword, word2vec_model, max_len) for keyword in keywords]
encoded_titles = [encode_title(title, word2idx, max_len) for title in titles]

# %%
import torch

encoded_titles = torch.tensor(encoded_titles, dtype=torch.long)
embedded_abstracts = torch.tensor(embedded_abstracts, dtype=torch.float32)
embedded_keywords = torch.tensor(embedded_keywords, dtype=torch.float32)

# Print shapes for verification
print("Encoded titles shape:", encoded_titles.shape)  # (num_samples, max_len)
print("Embedded abstracts shape:", embedded_abstracts.shape)  # (num_samples, max_len, embedding_dim)
print("Embedded keywords shape:", embedded_keywords.shape)  # (num_samples, max_len, embedding_dim)
# Out:
# Encoded titles shape: torch.Size([105883, 50])
# Embedded abstracts shape: torch.Size([105883, 50, 100])
# Embedded keywords shape: torch.Size([105883, 50, 100])

# %%
# Define the sizes (replace these with your specific values)
input_size = 200  # Size of the input vocabulary
output_size = len(word2idx) + 1  # Size of the output vocabulary
hidden_size = 512  # Size of the hidden layer (common choice)

# Initialize the Encoder and Decoder
encoder = Encoder(input_size, hidden_size)
decoder = Decoder(output_size, hidden_size)

# Initialize the Seq2Seq model
seq2seq_model = Seq2Seq(encoder, decoder)

# %%
from sklearn.model_selection import train_test_split
import torch

# Concatenate embedded abstracts and keywords to form input data
input_data = torch.cat((embedded_abstracts, embedded_keywords), dim=-1)
indices = torch.arange(input_data.size(0))

# Split the data into train and test sets (80% train, 20% test)
train_inputs, test_inputs, train_titles, test_titles, train_indices, test_indices = train_test_split(input_data, encoded_titles, indices, test_size=0.2)

# %%
# Create idx_to_word dictionary for mapping indices back to words
idx_to_word = {idx: word for word, idx in word2idx.items()}

# %%
# Model parameters
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(seq2seq_model.parameters(), lr=0.001)

epochs = 2
batch_size = 32

# Calculate the number of batches based on batch size
num_batches = len(train_inputs) // batch_size

for epoch in range(epochs):
    epoch_loss = 0  # Track epoch loss
    
    for i in range(num_batches):
        # Get batch of data
        start_idx = i * batch_size
        end_idx = min(start_idx + batch_size, len(train_inputs))
        
        # Select batch from tensors
        src = train_inputs[start_idx:end_idx]  # Abstract and Keyword embeddings
        trg = train_titles[start_idx:end_idx]  # Title encodings
        
        # Forward pass
        optimizer.zero_grad()
        output = seq2seq_model(src, trg)
        
        # Compute loss and backpropagation
        loss = criterion(output.view(-1, output_size), trg.view(-1))
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
    
    # Print average loss for each epoch
    avg_epoch_loss = epoch_loss / num_batches
    print(f"Epoch {epoch+1}, Average Loss: {avg_epoch_loss:.8f}")

print("Training completed.")
# Out:
# Epoch 1, Average Loss: 0.15598492
# Epoch 2, Average Loss: 0.01072013
# Training completed.

# %%
# Set model to evaluation mode
seq2seq_model.eval()

batch_size = 32

# Calculate the number of batches based on batch size
num_batches = len(test_inputs) // batch_size

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(seq2seq_model.parameters(), lr=0.001)

# Initialize variables for tracking test loss and predictions
test_loss = 0
predicted_titles = []
ground_truth_titles = []

with torch.no_grad():
    num_test_batches = len(test_inputs) // batch_size
    
    for i in range(num_test_batches):
        start_idx = i * batch_size
        end_idx = min(start_idx + batch_size, len(test_inputs))

        src = test_inputs[start_idx:end_idx]
        trg = test_titles[start_idx:end_idx]

        # Forward pass
        output = seq2seq_model(src, trg)

        # Compute loss
        loss = criterion(output.view(-1, output_size), trg.view(-1))
        test_loss += loss.item()

        # Decode predicted title tokens to words
        _, predicted_indices = output.max(dim=2)
        
        for j in range(batch_size):
            predicted_title = [idx_to_word[idx.item()] for idx in predicted_indices[j] if idx.item() != 0]
            predicted_titles.append(predicted_title)

            ground_truth_title = [idx_to_word[idx.item()] for idx in trg[j] if idx.item() != 0]
            ground_truth_titles.append(ground_truth_title)

# Calculate average test loss
avg_test_loss = test_loss / num_test_batches
print(f"Average Test Loss: {avg_test_loss:.8f}")
# Out:
# Average Test Loss: 0.00638555

# %%
for i in range(50):
    index = test_indices[i].item()

    print(f"Sample {i+1}")
    print("Ground Truth Title:", " ".join(ground_truth_titles[i]))
    print("Predicted Title:  ", " ".join(predicted_titles[i]))
    print("Abstract:  ", "".join(abstracts.iloc[index]))
    print("Keywords:  ", "".join(keywords.iloc[index]))
    print("-" * 50)
# Out:
# Sample 1
# Ground Truth Title: myanmar election panel say aung san suu kyi party majority
# Predicted Title:   myanmar election panel say aung san suu kyi party majority
# Abstract:   news national league democracy taken 348 seat parliament reinforces rout military backed ruling party landmark election
# Keywords:   ['myanmar', 'election', 'aung san suu kyi', 'thein sein', 'defense military force']
# --------------------------------------------------
# Sample 2
# Ground Truth Title: never bernie voter threw biden changed primary
# Predicted Title:   never bernie voter threw biden changed primary
# Abstract:   bernie sander new hampshire nevada campaign hit roadblock wide range democrat would anything stop joe biden became vehicle
# Keywords:   ['biden joseph r jr', 'sander bernard', 'democratic party', 'presidential election 2020', 'primary caucus', 'voting voter', 'poll public opinion', 'buttigieg pete 1982', 'warren elizabeth', 'united state politics government']
# --------------------------------------------------
# Sample 3
# Ground Truth Title: 7 hamas member killed tunnel collapse gaza
# Predicted Title:   7 hamas member killed tunnel collapse gaza
# Abstract:   men repairing old cross border tunnel eastern gaza used war last year collapsed hamas said four worker survived
# Keywords:   ['palestinian', 'bridge tunnel', 'hamas', 'gaza strip', 'israel', 'defense military force', 'death fatality']
# --------------------------------------------------
# Sample 4
# Ground Truth Title: come hard part joe biden
# Predicted Title:   come hard part joe biden
# Abstract:   become presumptive democratic presidential nominee ally aiming win bernie sander younger liberal voter unify party
# Keywords:   ['biden joseph r jr', 'sander bernard', 'democratic party', 'presidential election 2020', 'primary caucus', 'voting voter', 'trump donald j', 'democratic national committee']
# --------------------------------------------------
# Sample 5
# Ground Truth Title: south carolina democratic debate expert weigh
# Predicted Title:   south carolina democratic debate expert weigh
# Abstract:   campaign veteran reacted democratic presidential candidate fared tuesday night
# Keywords:   ['presidential election 2020', 'debate political']
# --------------------------------------------------
# Sample 6
# Ground Truth Title: canada today seeking friend climate first contest
# Predicted Title:   canada today seeking friend climate first contest
# Abstract:   cabinet minister reach american state climate change plus chat prime minister justin trudeau end pirate joe
# Keywords:   ['canada', 'global warming', 'trudeau justin', 'bombardier inc']
# --------------------------------------------------
# Sample 7
# Ground Truth Title: winn parish louisiana covid case risk tracker
# Predicted Title:   dutchess parish louisiana covid case risk tracker
# Abstract:   see latest chart map coronavirus case death hospitalization winn parish louisiana
# Keywords:   ['coronavirus 2019 ncov', 'state u', 'death fatality', 'united state', 'disease rate']
# --------------------------------------------------
# Sample 8
# Ground Truth Title: khmer rouge warden asks freed
# Predicted Title:   khmer rouge warden asks freed
# Abstract:   trial former khmer rouge prison chief ended friday defendant unexpectedly asking set free despite admission guilt
# Keywords:   ['war crime genocide crime humanity', 'kaing guek eav', 'khmer rouge', 'cambodia']
# --------------------------------------------------
# Sample 9
# Ground Truth Title: qantas say would back suit flight attendant called racist
# Predicted Title:   qantas say would back suit flight attendant called racist
# Abstract:   musician posted name photograph airline employee twitter dispute flight australia
# Keywords:   ['airline airplane', 'racial profiling', 'qantas airway', 'australia']
# --------------------------------------------------
# Sample 10
# Ground Truth Title: india aam aadmi party sweep election delhi
# Predicted Title:   india aam aadmi party sweep election delhi
# Abstract:   party anticorruption campaigner arvind kejriwal 67 70 seat delhi assembly promise helping poor
# Keywords:   ['india', 'kejriwal arvind', 'modi narendra', 'corruption institutional', 'bribery kickback', 'aam aadmi party india', 'bharatiya janata party', 'indian national congress', 'gandhi rahul', 'new delhi india']
# --------------------------------------------------
# Sample 11
# Ground Truth Title: orlando police radio call
# Predicted Title:   orlando police radio call
# Abstract:   radio transmission orlando police department dispatcher reflect hour chaos followed first report gunshot crowded pulse nightclub june 12
# Keywords:   []
# --------------------------------------------------
# Sample 12
# Ground Truth Title: north korean leader may visit moscow russia say
# Predicted Title:   north korean leader may visit moscow russia say
# Abstract:   possible visit would kim jong un first trip abroad since taking control country late 2011 official said
# Keywords:   ['kim jong un', 'russia', 'north korea', 'international relation', 'moscow russia']
# --------------------------------------------------
# Sample 13
# Ground Truth Title: fact blur online feud end draw
# Predicted Title:   fact blur online feud end draw
# Abstract:   although threat zeta pushed hacker movement anonymous end opcartel project group vowed eventually undermine mexico drug cartel exposing corrupt official
# Keywords:   ['drug cartel', 'kidnapping', 'mexico', 'drug abuse traffic', 'anonymous internet group', 'cyberattacks hacker', 'zeta', 'organized crime']
# --------------------------------------------------
# Sample 14
# Ground Truth Title: donald trump tell georgia crowd critic take joke
# Predicted Title:   donald trump tell georgia crowd critic take joke
# Abstract:   donald j trump full attack mode campaign rally macon ga egged man insulted president obama lit senator bernie sander hillary clinton several fellow republican candidate
# Keywords:   ['presidential election 2016', 'clinton hillary rodham', 'obama barack', 'sander bernard', 'trump donald j', 'macon ga']
# --------------------------------------------------
# Sample 15
# Ground Truth Title: john kasich ad assails donald trump mocking disabled reporter
# Predicted Title:   john kasich ad assails donald trump mocking disabled reporter
# Abstract:   gov john kasich ohio took donald j trump task new advertisement paint billionaire businessman heartless presidency highlight recent mocking disabled reporter
# Keywords:   ['presidential election 2016', 'september 11 2001', 'kasich john r', 'trump donald j', 'new york time', 'washington post', 'ohio']
# --------------------------------------------------
# Sample 16
# Ground Truth Title: new interior minister revives debate muslim true german
# Predicted Title:   new interior minister revives debate muslim true german
# Abstract:   germany new interior minister reignited charged debate role muslim society saying islam part german way life
# Keywords:   ['germany', 'islam', 'interior department', 'merkel angela']
# --------------------------------------------------
# Sample 17
# Ground Truth Title: iranian close rank behind leader u kill popular general
# Predicted Title:   iranian close rank behind leader u kill popular general
# Abstract:   death qassim suleimani strengthened hand hard liner expert say undermined tried normalize relation west
# Keywords:   ['iran', 'suleimani qassim', 'khamenei ali', 'rouhani hassan', 'politics government', 'defense military force', 'trump donald j', 'united state international relation', 'united state defense military force', 'targeted killing', 'embargo sanction', 'terrorism', 'islamic revolutionary guard corp', 'quds force', 'baghdad iraq']
# --------------------------------------------------
# Sample 18
# Ground Truth Title: 2 adviser abducted somalia
# Predicted Title:   2 adviser abducted somalia
# Abstract:   two frenchman kidnapped hotel somalia perilous capital tuesday renegade faction somalia security force somali western official said
# Keywords:   ['somalia', 'kidnapping', 'france', 'mogadishu somalia', 'hostage']
# --------------------------------------------------
# Sample 19
# Ground Truth Title: yulin dog meat festival proceeds despite protester
# Predicted Title:   yulin dog meat festival proceeds despite protester
# Abstract:   sale dog meat city yulin third last year festival according report animal right activist called end holiday
# Keywords:   ['animal abuse right welfare', 'dog', 'humane society international', 'china', 'guangxi china', 'yulin china']
# --------------------------------------------------
# Sample 20
# Ground Truth Title: howard schultz draw protester hometown seattle
# Predicted Title:   howard schultz draw protester hometown seattle
# Abstract:   mr schultz former chief executive starbucks greeted 40 protester event saying would consider running president independent
# Keywords:   ['schultz howard', 'presidential election 2020', 'starbucks corporation', 'third party politics u', 'demonstration protest riot', 'seattle wash', 'united state politics government', 'trump donald j']
# --------------------------------------------------
# Sample 21
# Ground Truth Title: u marine involved deadly crash okinawa
# Predicted Title:   u marine involved deadly crash okinawa
# Abstract:   japan ministry foreign affair said nicholas james mclean driving influence alcohol
# Keywords:   ['military base installation', 'united state marine corp', 'drunken reckless driving', 'united state defense military force', 'okinawa ryukyu island japan', 'japan', 'united state international relation', 'death fatality', 'james mclean nicholas', 'taira hidemasa 2017']
# --------------------------------------------------
# Sample 22
# Ground Truth Title: mahmoud ahmadinejad ex president iran file run
# Predicted Title:   mahmoud ahmadinejad ex president iran file run
# Abstract:   surprising decision mr ahmadinejad became notorious west threatening israel denying existence holocaust may test iran establishment
# Keywords:   ['ahmadinejad mahmoud', 'rouhani hassan', 'khamenei ali', 'election court judiciary']
# --------------------------------------------------
# Sample 23
# Ground Truth Title: teenager attack jewish teacher marseille machete
# Predicted Title:   teenager attack jewish teacher marseille machete
# Abstract:   teenager told french police carried attack name god islamic state according marseille prosecutor
# Keywords:   ['islamic state iraq syria isi', 'rubin alissa johannsen', 'assault', 'france', 'marseille france', 'terrorism', 'hollande francois']
# --------------------------------------------------
# Sample 24
# Ground Truth Title: china pillory praise city based water pollution
# Predicted Title:   china pillory praise city based water pollution
# Abstract:   ministry environmental protection said plan monitor supply 338 city month name 10 best 10 worst
# Keywords:   ['china', 'water pollution']
# --------------------------------------------------
# Sample 25
# Ground Truth Title: suicide bomber attack u n building nigeria
# Predicted Title:   suicide bomber attack u n building nigeria
# Abstract:   suicide bomber driving vehicle packed explosive rammed main united nation building nigerian capital friday spreading panic among citizen
# Keywords:   ['nigeria', 'bomb explosive']
# --------------------------------------------------
# Sample 26
# Ground Truth Title: obama state union
# Predicted Title:   obama state union
# Abstract:   image president obama 2011 address congress nation
# Keywords:   ['obama barack', 'state union message u']
# --------------------------------------------------
# Sample 27
# Ground Truth Title: theory grow without fact lost flight
# Predicted Title:   theory grow without fact lost flight
# Abstract:   news program chat room aviation expert less informed tried explain modern jet like malaysia airline flight 370 could disappear without trace
# Keywords:   ['aviation accident safety', 'eckholm erik', 'malaysia airline', 'news news medium', 'malaysia', 'malaysia airline flight 370']
# --------------------------------------------------
# Sample 28
# Ground Truth Title: shrinking europe military spending stir concern
# Predicted Title:   shrinking europe military spending stir concern
# Abstract:   financial crisis seen taking toll individual country defense capability well role helping united state finance nato
# Keywords:   ['erlanger steven', 'europe', 'defense military force', 'north atlantic treaty organization', 'european sovereign debt crisis 2010', 'united state international relation', 'brussels belgium']
# --------------------------------------------------
# Sample 29
# Ground Truth Title: inquiry mine collapse chile end charge
# Predicted Title:   inquiry mine collapse chile end charge
# Abstract:   three year chilean mine collapse 33 men rescued investigation concluded neither mine owner mining agency responsible
# Keywords:   ['accident safety', 'mine mining', 'court judiciary', 'chile']
# --------------------------------------------------
# Sample 30
# Ground Truth Title: trash avalanche toll rise ethiopia survivor ask
# Predicted Title:   trash avalanche toll rise ethiopia survivor ask
# Abstract:   landfill edge addis ababa least 113 people died capital main dumping ground decade
# Keywords:   ['addis ababa ethiopia', 'avalanche', 'ethiopia', 'waste material disposal']
# --------------------------------------------------
# Sample 31
# Ground Truth Title: north korea launch short range projectile seoul say
# Predicted Title:   north korea launch short range projectile seoul say
# Abstract:   projectile launched east coast landed sea korean peninsula japan south korean military said
# Keywords:   ['missile missile defense system', 'north korea', 'south korea', 'defense military force', 'nuclear test']
# --------------------------------------------------
# Sample 32
# Ground Truth Title: greece replaces finance minister
# Predicted Title:   greece replaces finance minister
# Abstract:   evangelos venizelos named finance minister part broader cabinet reshuffle aimed restoring confidence among greek foreign creditor
# Keywords:   ['european sovereign debt crisis 2010', 'papandreou george', 'greece']
# --------------------------------------------------
# Sample 33
# Ground Truth Title: law sea treaty found capitol hill
# Predicted Title:   law sea treaty found capitol hill
# Abstract:   united nation treaty governs world ocean undergoing one periodic resurrection congress
# Keywords:   ['dempsey martin e', 'treaty', 'ocean sea', 'united state', 'arctic ocean', 'united state politics government', 'panetta leon e', 'law sea un convention', 'clinton hillary rodham', 'oil petroleum gasoline', 'strategic arm reduction treaty', 'kerry john', 'south china sea', 'embargo economic sanction']
# --------------------------------------------------
# Sample 34
# Ground Truth Title: ebola patient rejecting care
# Predicted Title:   ebola patient rejecting care
# Abstract:   amid deadliest ebola virus outbreak history doctor fighting disease also local population fear medical treatment
# Keywords:   ['ebola virus', 'epidemic', 'guinea', 'sierra leone', 'liberia']
# --------------------------------------------------
# Sample 35
# Ground Truth Title: brutal image syrian boy drowned turkey must seen activist say
# Predicted Title:   brutal image syrian boy drowned turkey must seen activist say
# Abstract:   photograph young refugee appeared timeline social medium debate broke ethic sharing graphic image
# Keywords:   ['kurdi aylan 2011 15', 'kurdi ghalib 2015', 'middle east africa migrant crisis', 'syria', 'turkey', 'drownings', 'news news medium', 'social medium', 'photography', 'europe', 'bodrum turkey', 'ko greece', 'maritime accident safety']
# --------------------------------------------------
# Sample 36
# Ground Truth Title: colombian rebel group resume attack cease fire end
# Predicted Title:   colombian rebel group resume attack cease fire end
# Abstract:   death reported attack highlighted challenge colombia face negotiating peace deal eln rebel group similar one signed larger farc group
# Keywords:   ['national liberation army colombia', 'colombia', 'santos juan manuel', 'revolutionary armed force colombia', 'politics government']
# --------------------------------------------------
# Sample 37
# Ground Truth Title: along road sorrow toddler lost name family life
# Predicted Title:   along road sorrow toddler lost name family life
# Abstract:   roadside bomb wiped family afghanistan except tiny girl arrived shepherd arm hospital one knew name called angel struggled survive
# Keywords:   ['afghanistan war 2001', 'improvised explosive device', 'refugee displaced person', 'afghanistan', 'islamic state iraq syria isi', 'death fatality']
# --------------------------------------------------
# Sample 38
# Ground Truth Title: overwhelmed virus paraguay considers ditching taiwan china vaccine
# Predicted Title:   overwhelmed virus paraguay considers ditching taiwan china vaccine
# Abstract:   paraguay government taiwan built thousand home poor upgraded health care system awarded hundred scholarship helped fund futuristic congress building alliance facing existential threat paraguay quest covid 19 vaccine becomes increasingly desperate
# Keywords:   ['internal essential']
# --------------------------------------------------
# Sample 39
# Ground Truth Title: beaming good cheer norwegian town dark day
# Predicted Title:   beaming good cheer norwegian town dark day
# Abstract:   three giant mirror mountain reflect sunlight onto small norwegian town get little winter everyone happy project
# Keywords:   ['daley suzanne', 'mirror', 'sunlight', 'science technology', 'rjukan norway', 'sun', 'norway']
# --------------------------------------------------
# Sample 40
# Ground Truth Title: 1915 paris pass second christmas eve war
# Predicted Title:   1915 paris pass second christmas eve war
# Abstract:   international herald tribune archive paris pass second christmas eve war quiet hope 1915
# Keywords:   ['christmas', 'world war 1914 18', 'paris france']
# --------------------------------------------------
# Sample 41
# Ground Truth Title: israeli agree reduce west bank roadblock
# Predicted Title:   israeli agree reduce west bank roadblock
# Abstract:   israel also promised secretary state condoleezza rice visiting upgrade checkpoint reduce waiting time palestinian
# Keywords:   ['palestinian', 'israel', 'security warning system', 'rice condoleezza', 'road traffic']
# --------------------------------------------------
# Sample 42
# Ground Truth Title: mexican police arrest alleged drug kingpin
# Predicted Title:   mexican police arrest alleged drug kingpin
# Abstract:   man known la barbie could extradited united state face charge cocaine trafficking
# Keywords:   ['drug abuse traffic', 'beltran leyva', 'calderon felipe', 'mexico']
# --------------------------------------------------
# Sample 43
# Ground Truth Title: hungary premier warns new spill caustic sludge
# Predicted Title:   hungary premier warns new spill caustic sludge
# Abstract:   prime minister viktor orban said high risk another spill 132 million gallon sludge crack reservoir wall
# Keywords:   ['hungarian aluminum production trade co', 'reservoir', 'accident safety', 'hazardous toxic substance', 'water pollution', 'hungary']
# --------------------------------------------------
# Sample 44
# Ground Truth Title: explosion kill 7 russian south ossetia
# Predicted Title:   explosion kill 7 russian south ossetia
# Abstract:   blast raised tension separatist enclave day scheduled pullback russian troop georgian territory
# Keywords:   ['georgia georgian republic', 'russia', 'bomb explosive', 'south ossetia georgian republic', 'medvedev dmitri']
# --------------------------------------------------
# Sample 45
# Ground Truth Title: timescast assange extradition possible
# Predicted Title:   timescast assange extradition possible
# Abstract:   november 2 2011 ravi somaiya london courthouse judge ruled wikileaks founder julian assange extradited sweden
# Keywords:   ['assange julian p', 'wikileaks', 'sweden', 'extradition', 'sexual harassment']
# --------------------------------------------------
# Sample 46
# Ground Truth Title: coronavirus put fore improbable u k leader dominic raab
# Predicted Title:   coronavirus put fore improbable u k leader dominic raab
# Abstract:   prime minister boris johnson intensive care untested foreign secretary guiding britain one greatest peacetime crisis
# Keywords:   ['great britain withdrawal eu brexit', 'coronavirus 2019 ncov', 'conservative party great britain', 'johnson boris', 'raab dominic 1974', 'politics government', 'great britain']
# --------------------------------------------------
# Sample 47
# Ground Truth Title: china 400 billion iran deal could deepen influence mideast
# Predicted Title:   china 400 billion iran deal could deepen influence mideast
# Abstract:   country signed sweeping pact saturday call heavy chinese investment iran 25 year exchange oil step could ease iran international isolation
# Keywords:   ['china', 'iran', 'foreign investment', 'oil petroleum gasoline', 'international relation', 'economic condition trend', 'embargo sanction', 'united state international relation']
# --------------------------------------------------
# Sample 48
# Ground Truth Title: russia 4 die north caucasus raid
# Predicted Title:   russia 4 die north caucasus raid
# Abstract:   member russia security service killed four men suspected militant stormed apartment building tense overnight standoff north caucasus region
# Keywords:   ['reevell patrick', 'caucasus russia', 'death fatality', 'russia', 'khandokhov arsen']
# --------------------------------------------------
# Sample 49
# Ground Truth Title: indian born tibetan allowed vote take offer
# Predicted Title:   indian born tibetan allowed vote take offer
# Abstract:   indian born tibetan reluctant register voter fear step toward integrating country hope leave one day true home
# Keywords:   ['election', 'immigration emigration', 'refugee displaced person', 'voter registration requirement', 'dalai lama', 'sangay lobsang', 'tsundue tenzin', 'aam aadmi party india', 'bharatiya janata party', 'indian national congress', 'china', 'dharamsala india', 'india', 'tibet']
# --------------------------------------------------
# Sample 50
# Ground Truth Title: premier action iraq raise u concern
# Predicted Title:   premier action iraq raise u concern
# Abstract:   night raid mass arrest come united state prepares leave iraq leading western official question country course prime minister nuri kamal al maliki
# Keywords:   ['iraq', 'maliki nuri kamal al', 'iraq war 2003', 'united state international relation', 'iran', 'baath party', 'politics government']
# --------------------------------------------------

# %%
import torch

# Specify the path where you want to save the model
model_path = 'seq2seq_model.pth'

# Save the model's state_dict
torch.save({
    'model_state_dict': seq2seq_model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),  # If you want to save the optimizer as well
}, model_path)

print(f"Model saved to {model_path}")
# Out:
# Model saved to seq2seq_model.pth

# %%
# Specify the path where the model was saved
model_path = 'seq2seq_model.pth'

# Initialize the model architecture
seq2seq_model = Seq2Seq(encoder, decoder)
optimizer = torch.optim.Adam(seq2seq_model.parameters())  # Initialize optimizer if saved

# Load the saved state_dict into the model and optimizer
checkpoint = torch.load(model_path)
seq2seq_model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

# Set the model to evaluation mode if you plan on evaluating
seq2seq_model.eval()
print("Model loaded and ready for evaluation.")
# Out:
# C:\Users\jackh\AppData\Local\Temp\ipykernel_20992\2302307036.py:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path)
# Model loaded and ready for evaluation.
